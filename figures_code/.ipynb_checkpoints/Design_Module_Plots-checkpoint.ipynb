# %% [markdown]
# # This code reproduces the violin plots used to analyze the design module results.

# %%
# import statements 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sp
import numpy as np

import sys
sys.path.insert(1, '../main_classes/')
from integrated_design_helpers import final_plot
# Out:
# Using TensorFlow backend.
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
plot_path = '../exemplars/rbs/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# T-test comparing original to mutated: -0.769 with p-val 0.44172
# T-test comparing original to STORM: -0.138 with p-val 0.89059
# T-test comparing mutated to STORM: 0.036 with p-val 0.97162
# Random
# T-test comparing original to mutated: 2.269 with p-val 0.02334
# T-test comparing original to STORM: 1.319 with p-val 0.19007
# T-test comparing mutated to STORM: 0.834 with p-val 0.40456
# Top 10%
# T-test comparing original to mutated: 7.12 with p-val 0.0
# T-test comparing original to STORM: 7.523 with p-val 0.0
# T-test comparing mutated to STORM: 2.606 with p-val 0.0092

# %%
plot_path = '../exemplars/glycans_immunogenic/outputs/deepswarm/binary_classification/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Class0.0
# T-test comparing original to mutated: -0.009 with p-val 0.99293
# T-test comparing original to STORM: -1.069 with p-val 0.28735
# T-test comparing mutated to STORM: -1.058 with p-val 0.29006
# Class1.0
# T-test comparing original to mutated: 0.195 with p-val 0.84507
# T-test comparing original to STORM: -0.415 with p-val 0.67877
# T-test comparing mutated to STORM: -0.449 with p-val 0.65346

# %%
plot_path = '../exemplars/toeholds/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# T-test comparing original to mutated: -2.401 with p-val 0.01637
# T-test comparing original to STORM: -3.346 with p-val 0.00114
# T-test comparing mutated to STORM: -2.48 with p-val 0.01317
# Random
# T-test comparing original to mutated: 1.265 with p-val 0.20606
# T-test comparing original to STORM: -0.728 with p-val 0.46835
# T-test comparing mutated to STORM: -1.018 with p-val 0.30861
# Top 10%
# T-test comparing original to mutated: 5.949 with p-val 0.0
# T-test comparing original to STORM: -0.075 with p-val 0.94037
# T-test comparing mutated to STORM: -1.37 with p-val 0.1707

# %%
plot_path = '../exemplars/toeholds/outputs/deepswarm/binary_classification/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# T-test comparing original to mutated: 13.282 with p-val 0.0
# T-test comparing original to STORM: -3.27 with p-val 0.00146
# T-test comparing mutated to STORM: -14.397 with p-val 0.0
# Random
# T-test comparing original to mutated: 18.586 with p-val 0.0
# T-test comparing original to STORM: 1.068 with p-val 0.28803
# T-test comparing mutated to STORM: 0.234 with p-val 0.81536
# Top 10%
# T-test comparing original to mutated: 58.321 with p-val 0.0
# T-test comparing original to STORM: -0.618 with p-val 0.53825
# T-test comparing mutated to STORM: -14.042 with p-val 0.0

# %%
plot_path = '../exemplars/peptides/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Random
# T-test comparing original to mutated: 2.576 with p-val 0.01001
# T-test comparing original to STORM: 1.397 with p-val 0.16552
# T-test comparing mutated to STORM: 0.942 with p-val 0.34599

# %%
plot_path = '../exemplars/peptides/outputs/deepswarm/binary_classification/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Random
# T-test comparing original to mutated: -1.201 with p-val 0.22994
# T-test comparing original to STORM: -0.836 with p-val 0.40491
# T-test comparing mutated to STORM: -0.547 with p-val 0.58467

# %%
plot_path = '../exemplars/peptides/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Random
# T-test comparing original to mutated: 2.576 with p-val 0.01001
# T-test comparing original to STORM: 1.397 with p-val 0.16552
# T-test comparing mutated to STORM: 0.942 with p-val 0.34599

# %%
plot_path = '../exemplars/large_synthetic_nucleic_acids/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# T-test comparing original to mutated: -2.351 with p-val 0.01877
# T-test comparing original to STORM: 6.553 with p-val 0.0
# T-test comparing mutated to STORM: 5.435 with p-val 0.0
# Random
# T-test comparing original to mutated: -0.002 with p-val 0.99805
# T-test comparing original to STORM: 15.361 with p-val 0.0
# T-test comparing mutated to STORM: 12.02 with p-val 0.0
# Top 10%
# T-test comparing original to mutated: 1.878 with p-val 0.06044
# T-test comparing original to STORM: 21.227 with p-val 0.0
# T-test comparing mutated to STORM: 17.316 with p-val 0.0
