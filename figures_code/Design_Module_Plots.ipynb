# %% [markdown]
# # This code reproduces the violin plots used to analyze the design module results.

# %%
# import statements 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sp

# %%
def final_plot(dfplot, plot_path, plot_name):
    sns.set_style('white')
    palette = ['cornflowerblue', 'navy', 'darkorange']
    dfplot['Method Type'] = [x.split('-')[1] for x in list(dfplot['method'])]
    for name, smalldf in dfplot.groupby('Method Type'):
        fig, ax = plt.subplots(figsize = (2,2), dpi = 300)
        sns.violinplot(
            data=smalldf, x='method', y='preds',palette = palette,
            saturation = 0.6,   linewidth=0.75, fliersize=1)
        new_labels = [x.get_text().split('-')[0] for x in ax.get_xticklabels()]
        ax.set_xticklabels(new_labels,rotation=90)   
        ax.spines['left'].set_visible(True)
        ax.spines['bottom'].set_visible(True)
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.set_title(name)
        ax.set_ylabel('Predictions')
        ax.set_xlabel('Method')
        plt.tight_layout()
        plt.savefig(plot_path + name + '_violinplot' + plot_name)
        plt.savefig(plot_path + name + '_violinplot' + plot_name + '.svg')
        plt.show()
        
    print("Computing statistics between different groups...")
    for method, smalldf in dfplot.groupby('Method Type'):
        print(method)
        original = smalldf[['Original' in name for name in smalldf['method']]]
        mutated = smalldf[['Mutated' in name for name in smalldf['method']]]
        storm = smalldf[['STORM' in name for name in smalldf['method']]]
        print('Comparing original to mutated: ', sp.ttest_ind(original['preds'], mutated['preds']))
    
        if len(storm) > 0:
            print('Comparing original to STORM: ', sp.ttest_ind(original['preds'], storm['preds']))
            print('Comparing mutated to STORM: ', sp.ttest_ind(mutated['preds'], storm['preds']))

# %%
plot_path = '../exemplars/rbs/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-1.996982689490325, pvalue=0.045829181959719384)
# Comparing original to STORM:  Ttest_indResult(statistic=-3.344734596401238, pvalue=0.0011497438472578597)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-2.445385261081145, pvalue=0.014471090004809102)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=0.6041154651067053, pvalue=0.5457679517083536)
# Comparing original to STORM:  Ttest_indResult(statistic=-2.370743392530352, pvalue=0.01961256007105369)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-2.3345725382967424, pvalue=0.019567305623325794)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=7.384906171825821, pvalue=1.5349527434953408e-13)
# Comparing original to STORM:  Ttest_indResult(statistic=4.278206985106615, pvalue=4.227255162683123e-05)
# ...

# %%
plot_path = '../exemplars/glycans_immunogenic/outputs/deepswarm/binary_classification/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Class0.0
# Comparing original to mutated:  Ttest_indResult(statistic=0.20659154577752678, pvalue=0.836329370466487)
# Comparing original to STORM:  Ttest_indResult(statistic=-1.0273874486123677, pvalue=0.3066447492289228)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-1.0386212180759185, pvalue=0.2989839651491296)
# Class1.0
# Comparing original to mutated:  Ttest_indResult(statistic=0.36198407745681777, pvalue=0.7173648491037232)
# Comparing original to STORM:  Ttest_indResult(statistic=-0.6329701106715142, pvalue=0.5281559959598077)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-0.6491654000956006, pvalue=0.516233268532188)

# %%
plot_path = '../exemplars/toeholds/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-7.43850927707381, pvalue=1.020294878651833e-13)
# Comparing original to STORM:  Ttest_indResult(statistic=-4.80544441553466, pvalue=5.27106244019729e-06)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-0.10986042675964196, pvalue=0.9125201224137506)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=0.7882861537754666, pvalue=0.4305298112092554)
# Comparing original to STORM:  Ttest_indResult(statistic=-1.5781102119446357, pvalue=0.11760667445923881)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-1.3602726897261805, pvalue=0.17374441275095598)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=6.607876139362855, pvalue=3.903577184425301e-11)
# Comparing original to STORM:  Ttest_indResult(statistic=-0.7626491124526924, pvalue=0.4474157581457675)
# ...

# %%
plot_path = '../exemplars/toeholds/outputs/deepswarm/binary_classification/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=1.0121966481041038, pvalue=0.3114446497434918)
# Comparing original to STORM:  Ttest_indResult(statistic=-19.32410214521316, pvalue=4.9070366848064007e-36)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-25.343455768908953, pvalue=1.3733231707750603e-141)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=22.929461995282047, pvalue=2.808409449681023e-116)
# Comparing original to STORM:  Ttest_indResult(statistic=-4.004699095853285, pvalue=0.00011740726921945285)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-32.622602168893046, pvalue=3.976447960954028e-233)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=40.55408156950879, pvalue=0.0)
# Comparing original to STORM:  Ttest_indResult(statistic=9.354503744330682, pvalue=2.0155536587460637e-15)
# ...

# %%
plot_path = '../exemplars/peptides/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-2.324076694977696, pvalue=0.020126601729946812)
# Comparing original to STORM:  Ttest_indResult(statistic=-1.4125255702539998, pvalue=0.16080971388810011)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-0.8183995094110816, pvalue=0.41313421979894305)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=-0.533173000825822, pvalue=0.5939169312736394)
# Comparing original to STORM:  Ttest_indResult(statistic=-1.8880149556794585, pvalue=0.06183820470166683)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-1.7562243000620368, pvalue=0.0790581498807246)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=3.4961424711229907, pvalue=0.0004725728351057726)
# Comparing original to STORM:  Ttest_indResult(statistic=1.9284681833202053, pvalue=0.05654998019004167)
# ...

# %%
plot_path = '../exemplars/peptides/outputs/deepswarm/binary_classification/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Class0.0
# Comparing original to mutated:  Ttest_indResult(statistic=-0.1837009417071432, pvalue=0.8542490451757744)
# Comparing original to STORM:  Ttest_indResult(statistic=-2.0428520036958906, pvalue=0.04362098525781449)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-1.979163054463985, pvalue=0.04780483781679346)
# Class1.0
# Comparing original to mutated:  Ttest_indResult(statistic=1.214792389600215, pvalue=0.22445281167992442)
# Comparing original to STORM:  Ttest_indResult(statistic=-0.5506632886816077, pvalue=0.5830568951443045)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-0.8006170500166513, pvalue=0.42335838110568147)

# %%
plot_path = '../exemplars/peptides/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-2.324076694977696, pvalue=0.020126601729946812)
# Comparing original to STORM:  Ttest_indResult(statistic=-1.4125255702539998, pvalue=0.16080971388810011)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-0.8183995094110816, pvalue=0.41313421979894305)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=-0.533173000825822, pvalue=0.5939169312736394)
# Comparing original to STORM:  Ttest_indResult(statistic=-1.8880149556794585, pvalue=0.06183820470166683)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-1.7562243000620368, pvalue=0.0790581498807246)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=3.4961424711229907, pvalue=0.0004725728351057726)
# Comparing original to STORM:  Ttest_indResult(statistic=1.9284681833202053, pvalue=0.05654998019004167)
# ...

# %%
plot_path = '../exemplars/large_synthetic_nucleic_acids/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-3.9649600634274647, pvalue=7.343702542701192e-05)
# Comparing original to STORM:  Ttest_indResult(statistic=5.887464040907822, pvalue=4.9495307147288736e-08)
# Comparing mutated to STORM:  Ttest_indResult(statistic=4.8149834471087445, pvalue=1.473333095561743e-06)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=-0.06956820479057942, pvalue=0.9445374230072303)
# Comparing original to STORM:  Ttest_indResult(statistic=15.612541707144658, pvalue=6.598523808383869e-29)
# Comparing mutated to STORM:  Ttest_indResult(statistic=10.288589532985942, pvalue=8.0618118797640725e-25)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=3.309208190522068, pvalue=0.0009357888584856156)
# Comparing original to STORM:  Ttest_indResult(statistic=22.610581639774736, pvalue=9.89140616398095e-42)
# ...
