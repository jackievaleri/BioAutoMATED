# %% [markdown]
# # This code reproduces the violin plots used to analyze the design module results.

# %%
# import statements 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sp

# %%
def final_plot(dfplot, plot_path, plot_name):
    sns.set_style('white')
    palette = ['cornflowerblue', 'navy', 'darkorange']
    dfplot['Method Type'] = [x.split('-')[1] for x in list(dfplot['method'])]
    for name, smalldf in dfplot.groupby('Method Type'):
        fig, ax = plt.subplots(figsize = (2,2), dpi = 300)
        sns.violinplot(
            data=smalldf, x='method', y='preds',palette = palette,
            saturation = 0.6,   linewidth=0.75, fliersize=1)
        new_labels = [x.get_text().split('-')[0] for x in ax.get_xticklabels()]
        ax.set_xticklabels(new_labels,rotation=90)   
        ax.spines['left'].set_visible(True)
        ax.spines['bottom'].set_visible(True)
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.set_title(name)
        ax.set_ylabel('Predictions')
        ax.set_xlabel('Method')
        plt.tight_layout()
        plt.savefig(plot_path + name + '_violinplot' + plot_name)
        plt.savefig(plot_path + name + '_violinplot' + plot_name + '.svg')
        plt.show()
        
    print("Computing statistics between different groups...")
    for method, smalldf in dfplot.groupby('Method Type'):
        print(method)
        original = smalldf[['Original' in name for name in smalldf['method']]]
        mutated = smalldf[['Mutated' in name for name in smalldf['method']]]
        storm = smalldf[['STORM' in name for name in smalldf['method']]]
        print('Comparing original to mutated: ', sp.ttest_ind(original['preds'], mutated['preds']))
    
        if len(storm) > 0:
            print('Comparing original to STORM: ', sp.ttest_ind(original['preds'], storm['preds']))
            print('Comparing mutated to STORM: ', sp.ttest_ind(mutated['preds'], storm['preds']))

# %%
plot_path = '../final_exemplars/rbs_fullset/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-1.5474603404933396, pvalue=0.12175475879292942)
# Comparing original to STORM:  Ttest_indResult(statistic=-5.554953842736227, pvalue=2.184018475496994e-07)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-4.838349671397731, pvalue=1.3107411768288123e-06)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=0.9493118637922915, pvalue=0.3424638187672603)
# Comparing original to STORM:  Ttest_indResult(statistic=-0.3961601089358738, pvalue=0.6928064016414162)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-0.6135835857054659, pvalue=0.5394916272367105)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=9.559257055391853, pvalue=1.2070962646060492e-21)
# Comparing original to STORM:  Ttest_indResult(statistic=10.774775198647005, pvalue=1.4036047600263909e-18)
# Comparing mutated to STORM:  Ttest_indResult(statistic=3.4380378733325045, pvalue=0.0005861426306066754)

# %%
plot_path = '../final_exemplars/glycans_immunogenic/outputs/deepswarm/binary_classification/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Class0.0
# Comparing original to mutated:  Ttest_indResult(statistic=0.16228823507995233, pvalue=0.8710796816378044)
# Comparing original to STORM:  Ttest_indResult(statistic=nan, pvalue=nan)
# Comparing mutated to STORM:  Ttest_indResult(statistic=nan, pvalue=nan)
# Class1.0
# Comparing original to mutated:  Ttest_indResult(statistic=0.5568669128938001, pvalue=0.5776213378036189)
# Comparing original to STORM:  Ttest_indResult(statistic=nan, pvalue=nan)
# Comparing mutated to STORM:  Ttest_indResult(statistic=nan, pvalue=nan)
# /anaconda2/envs/automl_py37/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3703: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /anaconda2/envs/automl_py37/lib/python3.7/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_path = '../final_exemplars/toeholds/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-8.932391435983902, pvalue=4.1859777081236725e-19)
# Comparing original to STORM:  Ttest_indResult(statistic=-4.144656049568054, pvalue=6.997817153502677e-05)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-2.7898722067387993, pvalue=0.005273133996265585)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=3.5604350830580938, pvalue=0.0003702836762774911)
# Comparing original to STORM:  Ttest_indResult(statistic=-4.654289161312014, pvalue=9.713321395680045e-06)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-6.240007630139543, pvalue=4.379847700526984e-10)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=24.17701983996776, pvalue=4.807274767745544e-129)
# Comparing original to STORM:  Ttest_indResult(statistic=-0.3042187878543841, pvalue=0.7615749750934127)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-5.755119788231351, pvalue=8.664320755983715e-09)

# %%
plot_path = '../final_exemplars/peptides/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-2.193170310506644, pvalue=0.028301117275435824)
# Comparing original to STORM:  Ttest_indResult(statistic=-2.5773783135075043, pvalue=0.011370704464288346)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-1.9087682367832528, pvalue=0.056299501218943504)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=-0.7942326242871183, pvalue=0.4270649535928909)
# Comparing original to STORM:  Ttest_indResult(statistic=-3.461582522409441, pvalue=0.0007830819025765699)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-3.106455469712867, pvalue=0.0018948387204058142)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=2.0270535030708907, pvalue=0.04266388357322632)
# Comparing original to STORM:  Ttest_indResult(statistic=1.4326997792489926, pvalue=0.15497179380142928)
# Comparing mutated to STORM:  Ttest_indResult(statistic=1.1212042374379874, pvalue=0.26220801401750576)

# %%
plot_path = '../final_exemplars/synthetic_nucleic_acids/outputs/deepswarm/regression/design/'
dfplot = pd.read_csv(plot_path + 'sequences_all_methods.csv')
final_plot(dfplot, plot_path, '_design.png')
# Out:
# Computing statistics between different groups...
# Bottom 10%
# Comparing original to mutated:  Ttest_indResult(statistic=-3.9448112504606545, pvalue=7.989358255566476e-05)
# Comparing original to STORM:  Ttest_indResult(statistic=-30.758452387575748, pvalue=1.0136342204044072e-53)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-19.56419499517504, pvalue=3.843440046780586e-85)
# Random
# Comparing original to mutated:  Ttest_indResult(statistic=0.02586022627293624, pvalue=0.9793688534053862)
# Comparing original to STORM:  Ttest_indResult(statistic=-20.355324758587713, pvalue=6.971678646472774e-38)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-13.267604965572515, pvalue=3.729416568328745e-40)
# Top 10%
# Comparing original to mutated:  Ttest_indResult(statistic=3.547041777499846, pvalue=0.0003896833227210717)
# Comparing original to STORM:  Ttest_indResult(statistic=-11.327404816306254, pvalue=8.399805827018066e-20)
# Comparing mutated to STORM:  Ttest_indResult(statistic=-8.379119118855902, pvalue=5.370811209060037e-17)
